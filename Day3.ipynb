# %%
import pandas as pd
import numpy as np
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'pandas (Python 3.14.4)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
